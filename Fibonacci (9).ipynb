# %%
# Serie de Fibonaci

a=0
b=1


c=int(input("ingrese cuantos valores quiere: "))
print(a)
print(b)
for i in range (c-2):
  s=a+b
  a=b
  b=s
  print(s)
# Out:
# ingrese cuantos valores quiere: 8
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
