# %%
a=int(input("ingrese el primer número: "))
b=int(input("ingrese el segundo número: "))
operation_type=(input("ingrese el tipo de operación:suma, resta, multiplicación, división: "))

m=a*b
s=a+b
r=a-b
d=a/b

if operation_type == "multiplicación":
  print(m)
if operation_type == "suma":
  print(s)

if operation_type == "resta":
  print(r)

  if operation_type == "división":
     print(d)
# Out:
# ingrese el primer número: 2
# ingrese el segundo número: 2
# ingrese el tipo de operación:suma, resta, multiplicación, división: suma
# 4
