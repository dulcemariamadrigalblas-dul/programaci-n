# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
for i in range (1,11):
 print("hola mundo")
 print(i)
# Out:
# hola mundo
# 1
# hola mundo
# 2
# hola mundo
# 3
# hola mundo
# 4
# hola mundo
# 5
# hola mundo
# 6
# hola mundo
# 7
# hola mundo
# 8
# hola mundo
# 9
# hola mundo
# 10

# %%
a=int(input("ingrese la tabla de multiplicar: "))


for i in range (1,11):
  m=a*i
  print(i,"x",a,"=",m)
# Out:
# ingrese la tabla de multiplicar: 5
# 1 x 5 = 5
# 2 x 5 = 10
# 3 x 5 = 15
# 4 x 5 = 20
# 5 x 5 = 25
# 6 x 5 = 30
# 7 x 5 = 35
# 8 x 5 = 40
# 9 x 5 = 45
# 10 x 5 = 50

# %%
password= ""
while password!= "popotito":
  password=input("ingresa el password")
print("WELCOME")
# Out:
# ingresa el passworddjnkvn
# ingresa el passwordaaaa
# ingresa el passwordaaa
# ingresa el passwordpopotito
# WELCOME

# %%
usuario=""
password=""
while password!= "ibero" and usuario!="dul":
  usuario=input("ingresa el usuario")
  password=input("ingrese el password")
  print("WELCOME")
# Out:
# ingresa el usuariodul
# ingrese el passwordibero
# WELCOME
