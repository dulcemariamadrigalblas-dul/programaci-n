# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
c=int(input("pon tu calificación: "))


if(c>=70):
      print("felicidades aprobó")
      print(c)
elif(c<70 and c >50):
        print("segunda oportunidad")
else:
      print("reprobado")
# Out:
# pon tu calificación: 40
# reprobado

# %%
a=int(input("¿qué edad tienes?: "))

if(a<=12):
  print("eres niño o niña")
elif(a>12 and a <=17):
  print("eres adolescente")
elif(a>18 and a <=64):
  print("eres adulto")
else:
  print("eres adulto mayor")
# Out:
# ¿qué edad tienes?: 64
# eres adulto

# %%
a=(input("¿qué color ve?"))

if(a=="verde"):
  print("avanzar")
elif(a=="amarillo"):
  print("precaución")
elif(a=="rojo"):
  print("alto")
else:
  print("no aplica")
# Out:
# ¿qué color ve?rojo
# alto
